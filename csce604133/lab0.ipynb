# %% [markdown]
# # Hello

# %%
print("Hello")
# Out:
# Hello

# %%
from skimage import color, io
from skimage.transform import rescale
import matplotlib.pyplot as plt

# %%
i1 = io.imread("../static/lab0/fasilkom.png")

# %%
plt.imshow(i1, cmap="gray", vmin=0, vmax=255)
plt.show()

# %%
dimension = i1.shape
dimension
# Out:
# (480, 720)

# %%
io.imsave("../out/lab0/fasilkombaru.png", i1)

# %%
i2 = rescale(i1, 0.5, anti_aliasing=True)
plt.imshow(i2, cmap="gray")

# %%
i3 = rescale(i1, 0.1, anti_aliasing=True)
plt.imshow(i3, cmap="gray")
